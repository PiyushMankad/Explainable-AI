# %%
import pandas as pd
import re
import spacy   
import numpy as np
nlp = spacy.load('en_core_web_sm')

# %%
data = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Dissertation/all_nouns.csv").fillna("undefined")

# %%
def blend(X_train):
    final = []
    (rows, cols) = X_train.shape
    
    for row in range(rows):
        feature = ""
        for col in range(cols):
            feature += X_train.iloc[row][col] + " "
        final.append(feature)
    return final

# %%
x = pd.concat([data["Noun Phrases"],data["Noun"],data["Propernoun"]],axis=1)
data["new"] = blend(x)
x = data["new"]
y = data["Labels"]
x.head(10)
# Out:
# 0    planet_venus_starts new_year blaine_p_friedlan...
# 1    iowa_caucuses presidential_hopefuls tuesday_vo...
# 2    john_wall michael_lee john_wall locker_room br...
# 3    maryland_housing_office prince_georges financi...
# 4    southern_yemen sudarsan_raghavan southern_yeme...
# 5    jason_horowitz mitt_romney pam_arnold_powers r...
# 6    homicides_fall prince_georges allison_klein ma...
# 7    mike_shanahan right_direction barry_svrluga mi...
# 8    blue_jackets alex_ovechkin_scores katie_carrer...
# 9    warm_december martin_weil warm_december months...
# Name: new, dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
labels = oe.fit_transform(pd.DataFrame(y))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42, shuffle=True)
# y_train.toarray().reshape(-1,1)
# y_test.toarray().reshape(-1,1)
print(X_train.shape)
print(y_train.shape)
# Out:
# (8000,)
# (8000,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import RidgeClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.extmath import density
from sklearn import metrics

# %%
target_names = y.unique()
feature_names = []

# %%
def vectorize(vect,X_train,X_test,chisquare=False,n_features=10000):
    if vect == "hashing":
        vectorizer = HashingVectorizer(stop_words='english', alternate_sign=False,
                                       n_features=2 ** 16)
        X_train = vectorizer.transform(X_train)
    else:
        vectorizer = TfidfVectorizer(sublinear_tf=True, max_df=0.5,
                                     stop_words='english')
        X_train = vectorizer.fit_transform(X_train)
    X_test = vectorizer.transform(X_test)
    if vect == "hashing" :
        feature_names = None
    else:
        feature_names = vectorizer.get_feature_names()
    if chisquare:
        ch2 = SelectKBest(chi2, k=n_features)
        X_train = ch2.fit_transform(X_train, y_train)
        X_test = ch2.transform(X_test)
        if feature_names:
            # keep selected feature names
            feature_names = [feature_names[i] for i
                             in ch2.get_support(indices=True)]
        print("selected features using chi2")
    if feature_names:
        feature_names = np.asarray(feature_names)
        return X_train,X_test,feature_names
    return X_train,X_test

# %%
def benchmark(clf,print_top10 = True,print_report = False,num_keywords = -10):
    print("Training: ")
    print(clf)
    clf.fit(X_train, y_train)
    print("trained model")
    pred = clf.predict(X_test)
    print("predicted using model")

    score = metrics.accuracy_score(y_test, pred)
    print("accuracy:   %0.3f" % score)

    if hasattr(clf, 'coef_'):
        print("dimensionality: %d" % clf.coef_.shape[1])
        print("density: %f" % density(clf.coef_))

        if print_top10 and feature_names is not None:
            print("top 10 keywords per class:")
            for i, label in enumerate(target_names):
                try:
                    top10 = np.argsort(clf.coef_[i])[num_keywords:]
                    print("%s: %s" % (label, " ".join(feature_names[top10])))
                except:
                    print("\n\n####\nSomething went wrong, '{}' label might not have 10 features in total".format(label))
                    # print(clf.coef_[i])

        print()

    if print_report:
        print("classification report:")
        print(metrics.classification_report(y_test, pred,
                                            target_names=target_names))
    clf_descr = str(clf).split('(')[0]
    return clf_descr, score

# %%
print(X_train.shape)
print(y_train.shape)

X_train,X_test,feature_names = vectorize("tfidf",X_train,X_test,chisquare=False)
print(X_train.shape)
print(y_train.shape)
results = []
for clf, name in (
        (RidgeClassifier(tol=1e-2, solver="sag"), "Ridge Classifier"),
        (Perceptron(max_iter=100), "Perceptron"),
        (PassiveAggressiveClassifier(max_iter=100),
         "Passive-Aggressive"),
        (KNeighborsClassifier(n_neighbors=10), "kNN"),
        (LogisticRegression(n_jobs=1,C=1e5,max_iter=100),"lr"),
        (RandomForestClassifier(), "Random forest")):
    print('=' * 80)
    print(name)
    results.append(benchmark(clf))
# Out:
# (8000,)
# (8000,)
# (8000, 338805)
# (8000,)
# ================================================================================
# Ridge Classifier
# Training:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=None, solver='sag',
#                 tol=0.01)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:558: UserWarning: "sag" solver requires many iterations to fit an intercept with sparse inputs. Either set the solver to "auto" or "sparse_cg", or set a low "tol" and a high "max_iter" (especially if inputs are not standardized).
#   '"sag" solver requires many iterations to fit '
# trained model
# predicted using model
# accuracy:   0.713
# dimensionality: 338805
# density: 0.999964
# top 10 keywords per class:
# Local
# : laurel ct 18 grocery_store old_man lakes merchandise shoplifting feb_8_merchandise laurel_lakes_ct
# Politics
# : jan feb thefts break president_obama police romantic_recommendations states white_women undefined
# Wizards/NBA
# : jan property west east thefts motor hwy vehicle motor_vehicle_thefts jan_17_property
# Middle East
# : death i_dont patients comfort nursing belief wishes own_death ventilator worthwhile
# Redskins/NFL
# : mail loudoun 202 adoption_hours pet st_nw motor_vehicle_thefts jan_17_property undefined block
# Capitals/NHL
# : speech policies conservatives act discussion panel constitution connection panel_discussion us_constitution
# Sports
# : area border latino massachusetts attacks critics immigrants undefined flags american_flags
# Colleges
# : ohio measure health_care sen disclosure undefined point offices folks federal_offices
# Magazine
# : region ups accomplice jan lane vehicles windows cherrywood cherrywood_lane jan_24_windows
# Asia & Pacific
# : temperaments daughter fall_asleep parent parenting child kelly marguerite _margueritekellycom advice_
# World
# : sudanese_troops raghavan sudarsan_raghavan kenyans kenya darfur pengassan khartoum sudans sudan
# National Security
# : win senior aaa title tenorio paul_tenorio girls basketball boys junior
# Capital Business
# : delhi pakistans leiby india kabul nato islamabad pakistan beijing chinas
# Business
# : bookworld_ narrative author paperback memoir novels book_world novel book pp
# Education
# : consumer mufson analysts david_s_hilzenrath hilzenrath imf halzack sarah_halzack sec investors
# Books
# : censer abha bhattarai abha_bhattarai danielle marjorie_censer company firms danielle_douglas charity
# Obituaries
# : carrera katie_carrera defenseman mcphee nhl hunter vokoun ovechkin washington_capitals capitals
# Health & Science
# : cx acadia denali engine srx torque wheel horsepower nuts bolts
# AllMetSports
# : thompson tracee_hamilton clemson halftime mosley duke georgetown tracee terps hoyas
# Letters to the Editor
# : yjdp cappies_adult_mentors post mentors cappies_student_critics cappies_critics journalism workshop washington_post cappies
# Opinions
# : general_assembly tsp anita kumar anita_kumar ward john_wagner debonis tim_craig mike_debonis
# The Post's View
# : young_boys opener rosarios uniteds kansas_city dudar olsen mls_season_opener match pontius
# Style
# : low_cost recalibration lemming james_mcnerney_jr competitiveness mcnerney innovation incubators business_incubators collaborative_inspiration
# D.C. Politics
# : bill_turque jenna_johnson emma mathews achievement turque students schools teachers jay_mathews
# Discussions
# : weitz actor gomes tv viewers characters character hank stuever hank_stuever
# Going Out Guide
# : sarkozys edward_cody britains_leader putins cameron france britains minister putin moscow
# KidsPost
# : recipe pork sauce beer recommendations dave_mcintyre wines mcintyre recipes wine
# Maryland Politics
# : pg jane fritz_hahn kris guide guides_family_movie_reviews horwitz jane_horwitz kris_coronado coronado
# Europe
# : brian_vastag leitko whitney_fetterhoff aaron_leitko fetterhoff juliet_eilperin scientists disease study researchers
# Technology
# : latex backup_pump kee orchid orchids primer paint goldens colors c2
# Community Relations
# : startups singularity marty_nemko nemko example ceo innovations vivek wadhwa vivek_wadhwa
# Advice
# : detective peaceoholics cenziper closure specific_projects percent_closure_rate norris debbie_cenziper merriam closure_rate
# Wellness
# : bowen dickens kidsposts scientists animals tracy fun tracy_grant kidspost kids
# Innovations
# : mr ed metro march op feb page jan writer article
#  unit block: shevchek silpasuvan keenan guests weddings laclede ellen mccarthy ellen_mccarthy wedding
# Transportation
# : vicky_hallett overeaters hallett publication item_e yoga regimen registration publication_date fitness
#  6200 block: dunk mcgee john_wall michael_lee lin wall washington_wizards nba wittman wizards
#  14200 block: cody haiti croatians abbas europes croatians_vote edward_cody europes_capitals birnbaum michael_birnbaum
# D.C. United/Soccer
# : stanley_kwan hong_kong_stock_exchange kane_funeral_home kong seng_bank seng_index hang mr_kwan kwan seng
#
#
# ####
# Something went wrong, 'Home & Garden
# ' label might not have 10 features in total
#
#
# ####
# Something went wrong, ' 15600 block' label might not have 10 features in total
#
#
# ####
# Something went wrong, 'Maryland
# ' label might not have 10 features in total
#
# ================================================================================
# Perceptron
# Training:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#            fit_intercept=True, max_iter=100, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=0, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)
# trained model
# predicted using model
# accuracy:   0.680
# dimensionality: 338805
# density: 0.031769
# top 10 keywords per class:
# Local
# : grocery_store ct old_man 18 merchandise laurel lakes shoplifting laurel_lakes_ct feb_8_merchandise
# Politics
# : foot_office_development foot_office_building foot_office foot_museums foot_museum foot_motor_home foot_monopole foot_mini foot_mansion zzzzs
# Wizards/NBA
# : vehicle jan west property thefts east motor hwy motor_vehicle_thefts jan_17_property
# Middle East
# : i_dont place death belief patients comfort ventilator wishes own_death worthwhile
# Redskins/NFL
# : foot_traffic foot_toy_hoop foot_tower_crane foot_three foot_terrace foot_tenant_fit foot_surgery foot_studio_unit foot_store_march block
# Capitals/NHL
# : football_players football_players_tear football_power football_playoffs panel constitution discussion us_constitution connection panel_discussion
# Sports
# : foot_surgery foot_studio_unit foot_storm_surges foot_store_march foot_store foot_stone_wall foot_terrace zzzzs flags american_flags
# Colleges
# : football_playoffs football_players_tear football_players football_player football_program zzzzs offices folks point federal_offices
# Magazine
# : foot_stone_wall foot_steel_boat foot_tunnel foot_toy_hoop windows vehicles lane cherrywood cherrywood_lane jan_24_windows
# Asia & Pacific
# : behavior good_manners friend q_i stepsons parenting temperaments marguerite advice_ _margueritekellycom
# World
# : union khartoum chinese_workers murle nuer sudans likuangole kenya kenyans pengassan
# National Security
# : josh_barr wolverines prep 3a basketball tenorio paul_tenorio junior boys ice_hockey
# Capital Business
# : delhi beijing burning kabul andrew_higgins nato richard_leiby leiby islamabad chinas
# Business
# : yardley william_henry_harrison paperback nazi_seance arthur_j_magida magida gail_collins account book pp
# Education
# : investors sarah ezra sarah_halzack sec mufson steven_mufson bloomberg halzack analysts
# Books
# : oconnell danielle firms jonathan_oconnell catherine_ho danielle_douglas marjorie_censer marjorie censer region
# Obituaries
# : nhl mcphee tampa eastern_conference_standings tampa_bay ovechkin tomas capitals vokoun backstrom
# Health & Science
# : diesel bolts horsepower awd acadia sl nissan_juke_sl_awd juke gmc_acadia_denali denali
# AllMetSports
# : hoyas blue_devils bcs_championship_ratings pointers hollis field techs halftime depaul mosley
# Letters to the Editor
# : educational_foundation social_reader substantive_way year_award workshop personal_post washington_post_company cappies post washington_post
# Opinions
# : telework herrity anita tsp richmond craig debonis mike_debonis john_wagner tim_craig
# The Post's View
# : wolff young_boys josh_wolff robbie_russell rosarios defender mls_season_opener dudar match pontius
# Style
#  call 301-985-5060.   robberies kirkwood pl.: redskins grossman coaches rutherford regular_season mark_maske new_york_giants_crush_atlanta_falcons shanahan nfl nfl_playoffs
#  and thoughts of living pushed aside thoughts of dying. when the end does come: comcast play cindy ncaa_tournament rival_blue_devils ncaa boren cindy_boren post post_top
#  not a government program. on the other hand: dan_zak hesse jessica_goldstein hax monica_hesse carolyn carolyn_hax farhi paul_farhi moraes
#  3 p.m. jan. 13. a tip jar and juice were stolen from a donut shop. three people were seen fleeing with the property. belcrest rd.: documentary mcmullen premieres_sunday film amish hank stuever hank_stuever road_weve ganda
#  in burma: apples gb release zynga hayley tsukayama verge apple hayley_tsukayama stories
# Museums
# : juan angela bocaranda jungle fidel_castro castro juanita_castro angela_castro farc fidel
#  3500 block: fraud carbon topic legislation mr_mcdonnell regime editorial mr board editorial_board
#  preparing our residents for the jobs of tomorrow: petosa sicks nelson nelson_pressley shatners shatners_world revival pressley washington_improv_theaters_valentines_date_tips theaters
#  folger shakespeare library: aratani metrorail authority metro_transit_police longs transportation dc_songwriter_longs red_tops metros transit
# The Americas
# : spirit_airlines guests travel hotel snow amtrak christopher_elliott spirit sachs andrea_sachs
# TV
# : talent_economy abortion employer micron religious bolling governors_office juvenile juvenile_justice kaine
#  unit block: dawley youngblood nicolaides boatright ellen_mccarthy mcgoram shevchek veit keenan laclede
# Transportation
# : pounders_group lenny mental grief zumba lenny_bernstein anxiety_support_group publication_date fitness_regimen regimen
#  6200 block: franchise rashard nick dunk franchise_history lebron wall guys wittman wizards
#  14200 block: vanik brazil guards edward_cody european_union birnbaum michael_birnbaum croatians croatians_vote europes_capitals
# D.C. United/Soccer
# : stanley kane_funeral_home hong_kong_stock_exchange stanley_kwan index seng_bank seng_index hang mr_kwan seng
#
#
# ####
# Something went wrong, 'Home & Garden
# ' label might not have 10 features in total
#
#
# ####
# Something went wrong, ' 15600 block' label might not have 10 features in total
#
#
# ####
# Something went wrong, 'Maryland
# ' label might not have 10 features in total
#
# ================================================================================
# Passive-Aggressive
# Training:
# PassiveAggressiveClassifier(C=1.0, average=False, class_weight=None,
#                             early_stopping=False, fit_intercept=True,
#                             loss='hinge', max_iter=100, n_iter_no_change=5,
#                             n_jobs=None, random_state=None, shuffle=True,
#                             tol=0.001, validation_fraction=0.1, verbose=0,
#                             warm_start=False)
# trained model
# predicted using model
# accuracy:   0.738
# dimensionality: 338805
# density: 0.167914
# top 10 keywords per class:
# Local
# : grocery ct 18 lakes old_man grocery_store merchandise shoplifting feb_8_merchandise laurel_lakes_ct
# Politics
# : frontman_dan_auerbach frontline_workers frontline_work frontline_politics frontline_operator frontline_investigators frontline_employees frontline_agencies frontlines zzzzs
# Wizards/NBA
# : fugitive_zaeef east west property hwy thefts motor vehicle motor_vehicle_thefts jan_17_property
# Middle East
# : death i_dont comfort patients nursing belief wishes own_death ventilator worthwhile
# Redskins/NFL
# : frigid_air_westward frigid_afternoon frightful_screams frightening frighten_passengers frighten_commuters fright_fan frigid_sunshine zzzzs block
# Capitals/NHL
# : friendship_associations friendship_association_members friendship_area_motor_vehicle_thefts_rosemary_lane friendship_heights discussion panel connection constitution panel_discussion us_constitution
# Sports
# : friends_house friends_hope_publicity friends_home friends_happiness_underscores friends_garage friends_game friends_facebook zzzzs flags american_flags
# Colleges
# : frozen_leadership frozen_lakes frozen_lake frozen_ground frozen_frosting frozen_planets point offices folks federal_offices
# Magazine
# : friebe fridman frieden zzzzs lane vehicles windows cherrywood cherrywood_lane jan_24_windows
# Asia & Pacific
# : kids kelly parenting parent daughters daughter child marguerite _margueritekellycom advice_
# World
# : sudarsan raghavan sudarsan_raghavan kenyans darfur kenya khartoum pengassan sudans sudan
# National Security
# : aaa girls senior title basketball tenorio paul_tenorio ice_hockey junior boys
# Capital Business
# : delhi kabul richard_leiby nato leiby india pakistan islamabad beijing chinas
# Business
# : bookworld_ author novels paperback memoir narrative book_world novel book pp
# Education
# : bloomberg imf steven_mufson mufson sec hilzenrath david_s_hilzenrath analysts halzack sarah_halzack
# Books
# : firm catherine_ho region company censer marjorie_censer marjorie danielle_douglas firms charity
# Obituaries
# : boudreau tomas puck defenseman nhl mcphee hunter vokoun washington_capitals capitals
# Health & Science
# : acadia denali fuel srx torque engine wheel horsepower nuts bolts
# AllMetSports
# : mosley terps tracee_hamilton halftime tracee thompson depaul hoyas clemson blue_devils
# Letters to the Editor
# : cappies_adult_mentors atlas journalism cappies_critics cappies_student_critics mentors workshop post washington_post cappies
# Opinions
# : government_service tsp anita_kumar kumar agencies president_obamas_request john_wagner debonis mike_debonis tim_craig
# The Post's View
# : uniteds rosarios opener young_boys olsen kansas_city dudar mls_season_opener match pontius
# Style
# : low_cost recalibration james_mcnerney_jr lemming competitiveness mcnerney innovation incubators business_incubators collaborative_inspiration
# D.C. Politics
# : jenna students jenna_johnson mathews schools emma turque achievement teachers jay_mathews
# Discussions
# : producer scurlock characters weitz viewers gomes character hank stuever hank_stuever
# Going Out Guide
# : headlines sarkozys britains_leader paris cameron britains france putin minister moscow
# KidsPost
# : sauce beer dave_mcintyre vermouths white_vermouths_feeling recommendations mcintyre wines wine recipes
# Maryland Politics
# : 202 fritz horwitz guides_family_movie_reviews kris fritz_hahn guide jane_horwitz kris_coronado coronado
# Europe
# : fetterhoff kaiser brian_vastag leitko aaron_leitko juliet_eilperin disease readers_views study researchers
# Technology
# : gedeik latex margie orchids c2 orchid primer goldens paint colors
# Community Relations
# : startups nemko marty_nemko singularity vivek innovations ceo wadhwa vivek_wadhwa example
# Advice
# : adelson lanier specific_projects norris debbie_cenziper closure merriam housing percent_closure_rate closure_rate
# Wellness
# : fun_girl_scout_facts graders bowen scientists tracy tracy_grant animals fun kidspost kids
# Innovations
# : op tense metro march eating page feb article writer jan
# On Leadership
# : storage primer accessories kitchen garden terri terri_sapienza furniture sapienza damrosch
# Food
# : man manassas prince martin_weil police mccartney robert_mccartney dvorak kelly county
# Lifestyle
# : date weingarten gene_weingarten query amanda person_singular _work_advice date_lab daters karla
# Real Estate
# : manners shirts gaithersburg claire patricks st_patricks_day_parade langham dillingham parade sengbusch
# National
# : dimensions davis aaron county_officials victor countys victor_zapana zapana leggett aaron_c_davis
# Music
# : country mubarak ministry al world_news_coverage baghdad joel_greenberg parliament uprising cairo
# Travel
# : actor mr_farentino mr_gazzara ms_darcel gazzara darcel broadbent farentino movies films
# On Small Business
# : brougher catlin aitken design art kennicott museums annie_leibovitzs personal_pilgrimage philip_kennicott
# Entertainment
# : whitney operas trel recordings singers opera singer diva pop diva_whitney_houston
# Weddings
# : heirens coe vannatter dr_goodwin kline dr federal_coach women god lisa_miller
# Cars
# : deyoung pentagon official national_security_news us_officials security karen_deyoung national_security_coverage pincus walter_pincus
# Theater & Dance
# : thomas_boswell baseballs batting bryce baseball zimmerman clubhouse spring_training harper nationals
# World Business
# : retirement bob_doll damn bentley fake_candidate_costumes gate_february commemorate_presidents_day imagination bentley_gt8 gt8
# None
# : resident graduate daughter mrs bart complications mr bart_barnes grandchildren survivors
# Nationals/MLB
# : daughter_missy colo_dick_franklin boothe amy carmelita kinmont jeter shipley amy_shipley olympic
# Virginia Politics
# : twitter spielberg _post_lead_editor _lily_cunningham leaders facebook post_lead lily_cunningham tom_fox leadership
# Africa
# : entrepreneur businesses olga_khazan entrepreneurs khazan owners small_business_owners olga business small_business
# Movies
# : dana samuelson turkey outlook dionne opinions milbank dana_milbank _washpostcom postopinions
# Olympics
# : joe justices david_nakamura romney dan robert_barnes postpolitics campaign davidson joe_davidson
# Investigations
# : buyers harvey_s_jacobs house real_estate totalhomessold medianpurchaseprice neighborhoods homes estate neighborhood
#  call 301-985-5060.   robberies kirkwood pl.: qb goodell season regular_season mark_maske redskins yards shanahan nfl_playoffs nfl
#  and thoughts of living pushed aside thoughts of dying. when the end does come: steve_yanda yanda coach cindy_boren boren ncaa_tournament post ncaa rival_blue_devils post_top
#  not a government program. on the other hand: hesse jessica_goldstein freelance_writer hax lisa carolyn_hax farhi paul_farhi carolyn moraes
#  3 p.m. jan. 13. a tip jar and juice were stolen from a donut shop. three people were seen fleeing with the property. belcrest rd.: lovings documentary mcmullen amish episode road_weve ganda hank stuever hank_stuever
#  in burma: gb users ipad company verge hayley tsukayama apple hayley_tsukayama stories
# Museums
# : chavez raul colombia raul_castro capriles juan farc cuba fidel castro
#  3500 block: regime need corruption posts ms mr_obama board mr editorial editorial_board
#  preparing our residents for the jobs of tomorrow: revival broadway nelson improv nelson_pressley pressley theatre washington_improv_theaters_valentines_date_tips theater theaters
#  folger shakespeare library: dc_songwriter_longs halsey ashley_halsey_iii highway traffic metros aratani lori_aratani bike transit
# The Americas
# : tour www flights entrees hotel rooms andrea sachs travel andrea_sachs
# TV
# : micron governor religious cuccinellis cuccinelli allen governors_office juvenile juvenile_justice kaine
#  unit block: love keenan shevchek guests laclede weddings ellen mccarthy ellen_mccarthy wedding
# Transportation
# : vicky_hallett hallett zumba dance fitness_regimen registration publication_date yoga fitness regimen
#  6200 block: john_wall franchise_history lebron dunk lin wall nba washington_wizards wittman wizards
#  14200 block: croatians edward_cody haiti coup demonstrations croatians_vote abbas europes_capitals birnbaum michael_birnbaum
# D.C. United/Soccer
# : hong_kong_stock_exchange hong_kong hong kong seng_bank seng_index hang mr_kwan kwan seng
#
#
# ####
# Something went wrong, 'Home & Garden
# ' label might not have 10 features in total
#
#
# ####
# Something went wrong, ' 15600 block' label might not have 10 features in total
#
#
# ####
# Something went wrong, 'Maryland
# ' label might not have 10 features in total
#
# ================================================================================
# kNN
# Training:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')
# trained model
# predicted using model
# accuracy:   0.626
# ================================================================================
# lr
# Training:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='auto', n_jobs=1, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
